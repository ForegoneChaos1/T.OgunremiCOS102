# %%
# Simple Interest

P = float(input("Input Principal: "))
R = float(input("Input Rate: "))
T = float(input("Input Time: "))

SI = P * (1 + (R * T) / 100)

print("Simple Interest =", SI)

# Compound Interest

P = float(input("Input Principal: "))
R = float(input("Input Rate: "))
T = float(input("Input Time: "))
n = int(input("Number of times interest is compounded per year: "))

CI = P * (1 + R/n) ** (n * T)

print("Compound Interest =", CI)

# Annuity Plan

PMT = float(input("Input Payment: "))
R = float(input("Input Rate: "))
T = float(input("Input Time: "))
n = int(input("Number of payments per year: "))

A = PMT * ((1 + R/n) ** (n*t) -1)/ (R/n)

print("Annuity =", A)
# Out:
# Input Principal:  4
# Input Rate:  5
# Input Time:  6
# Simple Interest = 5.2
# Input Principal:  1000
# Input Rate:  0.05
# Input Time:  1
# Number of times interest is compounded per year:  3
# Compound Interest = 1050.8379629629628
